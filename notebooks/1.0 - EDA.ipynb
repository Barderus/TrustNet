# %% [markdown]
# # Import
# Import necessary library and frameworks for data exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
DATA_DIR = NOTEBOOK_DIR.parent / "data"
IMAGES_DIR = NOTEBOOK_DIR.parent / "images"
PREPROCESSED_DIR = DATA_DIR / "preprocessed"

IMAGES_DIR.mkdir(parents=True, exist_ok=True)
PREPROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Load data

# %%
df_newsnet_fake1 = pd.read_csv(DATA_DIR / "FakeNewsNet" / "gossipcop_fake.csv")
df_newsnet_real1 = pd.read_csv(DATA_DIR / "FakeNewsNet" / "gossipcop_real.csv")
df_newsnet_fake2 = pd.read_csv(DATA_DIR / "FakeNewsNet" / "politifact_fake.csv")
df_newsnet_real2 = pd.read_csv(DATA_DIR / "FakeNewsNet" / "politifact_real.csv")

df_kaggle_fake = pd.read_csv(DATA_DIR / "fake-news-kaggle" / "Fake.csv")
df_kaggle_true = pd.read_csv(DATA_DIR / "fake-news-kaggle" / "True.csv")

df_more = pd.read_csv(DATA_DIR / "More-fake-news" / "train.tsv", sep="	")

# %% [markdown]
# I have 3 different datasets, my goal is to analyze each one of them to see if I can merge them into a master dataset for fake news detection

# %%
print(df_newsnet_fake1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5323 entries, 0 to 5322
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         5323 non-null   str
#  1   news_url   5067 non-null   str
#  2   title      5323 non-null   str
#  3   tweet_ids  5135 non-null   str
# dtypes: str(4)
# memory usage: 12.1 MB
# None

# %%
print(df_newsnet_fake2.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         432 non-null    str
#  1   news_url   428 non-null    str
#  2   title      432 non-null    str
#  3   tweet_ids  392 non-null    str
# dtypes: str(4)
# memory usage: 3.1 MB
# None

# %%
print(df_newsnet_real1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16817 entries, 0 to 16816
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         16817 non-null  str
#  1   news_url   16804 non-null  str
#  2   title      16817 non-null  str
#  3   tweet_ids  15759 non-null  str
# dtypes: str(4)
# memory usage: 19.5 MB
# None

# %%
print(df_newsnet_real2.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         624 non-null    str
#  1   news_url   567 non-null    str
#  2   title      624 non-null    str
#  3   tweet_ids  409 non-null    str
# dtypes: str(4)
# memory usage: 7.9 MB
# None

# %%
df_newsnet_fake1["real"] = 0
df_newsnet_fake2["real"] = 0

df_newsnet_real1["real"] = 1
df_newsnet_real2["real"] = 1

# %% [markdown]
# Let's add our target variable to them.

# %%
df_newsnet = pd.concat([df_newsnet_fake1, df_newsnet_real1, df_newsnet_fake2, df_newsnet_real2], ignore_index=True)
df_newsnet
# Out:
#                          id  \
# 0      gossipcop-2493749932
# 1      gossipcop-4580247171
# 2       gossipcop-941805037
# 3      gossipcop-2547891536
# 4      gossipcop-5476631226
# ...                     ...
# 23191       politifact14731
# 23192         politifact329
# 23193        politifact1576
# 23194        politifact4720
# 23195          politifact52
#
#                                                 news_url  \
# 0      www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1      hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2      variety.com/2017/biz/news/tax-march-donald-tru...
# 3      www.dailymail.co.uk/femail/article-3499192/Do-...
# 4      variety.com/2018/film/news/list-2018-oscar-nom...
# ...                                                  ...
# 23191  https://www.flake.senate.gov/public/index.cfm/...
# 23192  https://web.archive.org/web/20080131000131/htt...
# 23193         http://www.youtube.com/watch?v=4O8CxZ1OD58
# 23194         http://www.youtube.com/watch?v=EhyMplwY6HY
# 23195  https://web.archive.org/web/20071102131244/htt...
#
#                                                    title  \
# 0      Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1      Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2      Celebrities Join Tax March in Protest of Donal...
# 3      Cindy Crawford's daughter Kaia Gerber wears a ...
# 4          Full List of 2018 Oscar Nominations – Variety
# ...                                                  ...
# 23191  Flake: “Religious tests should have no place i...
# 23192                           Change We Can Believe In
# 23193  deputy director of national health statistics ...
# 23194  Romneys ProLife Conversion Myth or Reality Jun...
# 23195                             Interest Group Ratings
#
#                                                tweet_ids  real
# 0      284329075902926848\t284332744559968256\t284335...     0
# 1      992895508267130880\t992897935418503169\t992899...     0
# 2      853359353532829696\t853359576543920128\t853359...     0
# 3      988821905196158981\t988824206556172288\t988825...     0
# 4      955792793632432131\t955795063925301249\t955798...     0
# ...                                                  ...   ...
# 23191                                                NaN     1
# 23192  634287923135909888\t946743411100536832\t946816...     1
# 23193                                                NaN     1
# 23194                                 188871706637647874     1
# 23195           1002208963239337984\t1024651239697666048     1
#
# [23196 rows x 5 columns]

# %%
df_kaggle_fake.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  str
#  1   text     23481 non-null  str
#  2   subject  23481 non-null  str
#  3   date     23481 non-null  str
# dtypes: str(4)
# memory usage: 60.4 MB

# %%
df_kaggle_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_kaggle_true.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  str
#  1   text     21417 non-null  str
#  2   subject  21417 non-null  str
#  3   date     21417 non-null  str
# dtypes: str(4)
# memory usage: 51.6 MB

# %%
df_kaggle_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_kaggle_fake["real"] = 0
df_kaggle_true["real"] = 1

# %%
df_kaggle = pd.concat([df_kaggle_fake, df_kaggle_true])

# %%
df_more
# Out:
#        Unnamed: 0                                              title  \
# 0            2619  Ex-CIA head says Trump remarks on Russia inter...
# 1           16043  YOU WON’T BELIEVE HIS PUNISHMENT! HISPANIC STO...
# 2             876  Federal Reserve governor Powell's policy views...
# 3           19963  SCOUNDREL HILLARY SUPPORTER STARTS “TrumpLeaks...
# 4           10783  NANCY PELOSI ARROGANTLY DISMISSES Questions on...
# ...           ...                                                ...
# 29995        6880  U.S. aerospace industry urges Trump to help Ex...
# 29996       17818  Highlights: Hong Kong leader Carrie Lam delive...
# 29997        5689  Obama Literally LAUGHS At Claims That Brexit M...
# 29998       15805  Syrian army takes full control of Deir al-Zor ...
# 29999        8143  U.S., Israel sign $38 billion military aid pac...
#
#                                                     text          subject  \
# 0      Former CIA director John Brennan on Friday cri...     politicsNews
# 1      How did this man come to OWN this store? There...  Government News
# 2      President Donald Trump on Thursday tapped Fede...     politicsNews
# 3      Hillary Clinton ally David Brock is offering t...        left-news
# 4      Pleading ignorance is a perfect ploy for Nancy...         politics
# ...                                                  ...              ...
# 29995  The chief executive of the U.S. Aerospace Indu...     politicsNews
# 29996  The following are highlights of the maiden pol...        worldnews
# 29997  If there s one thing President Barack Obama is...             News
# 29998  The Syrian army and its allies have taken full...        worldnews
# 29999  The United States will give Israel $38 billion...     politicsNews
#
#                       date  label
# 0           July 22, 2017       1
# 1             Jun 19, 2017      0
# 2        November 2, 2017       1
# 3             Sep 17, 2016      0
# 4             May 26, 2017      0
# ...                    ...    ...
# 29995    December 6, 2016       1
# 29996    October 11, 2017       1
# 29997        June 28, 2016      0
# 29998    November 2, 2017       1
# 29999  September 14, 2016       1
#
# [30000 rows x 6 columns]

# %%
df_more.rename(columns={"Unnamed: 0": "ID", "label":"real"}, inplace=True)

# %%
df_more.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       30000 non-null  int64
#  1   title    30000 non-null  str
#  2   text     30000 non-null  str
#  3   subject  30000 non-null  str
#  4   date     30000 non-null  str
#  5   real     30000 non-null  int64
# dtypes: int64(2), str(4)
# memory usage: 75.7 MB

# %% [markdown]
# Now we only have 3 datasets to work with:
# - `df_newsnet`
# - `df_kaggle`
# - `df_more`
# Where the target variable is called real, 0 = fake news, 1 = real news.
# The next steps is to identify, if possible the type of news to ensure no bias is being created towards a specific "genre". If all good, we can get everything together into a master file.

# %%
df_newsnet.columns
# Out:
# Index(['id', 'news_url', 'title', 'tweet_ids', 'real'], dtype='str')

# %%
df_kaggle.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'real'], dtype='str')

# %%
df_more.columns
# Out:
# Index(['ID', 'title', 'text', 'subject', 'date', 'real'], dtype='str')

# %%
sns.countplot(df_kaggle, x=df_kaggle["subject"])
plt.xlabel("Subject")
plt.ylabel("Count")
plt.xticks(rotation=315)
plt.title("Count of subjects - df_kaggle")
plt.savefig(IMAGES_DIR / "countSubjects.png")

# %%
sns.countplot(df_more, x=df_more["subject"])
plt.xlabel("Subject")
plt.ylabel("Count")
plt.xticks(rotation=315)
plt.title("Count of subjects - df_more")
plt.savefig(IMAGES_DIR / "countSubjects2.png")

# %%
df_news = pd.concat([df_kaggle, df_more])
df_news
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 29995  U.S. aerospace industry urges Trump to help Ex...
# 29996  Highlights: Hong Kong leader Carrie Lam delive...
# 29997  Obama Literally LAUGHS At Claims That Brexit M...
# 29998  Syrian army takes full control of Deir al-Zor ...
# 29999  U.S., Israel sign $38 billion military aid pac...
#
#                                                     text       subject  \
# 0      Donald Trump just couldn t wish all Americans ...          News
# 1      House Intelligence Committee Chairman Devin Nu...          News
# 2      On Friday, it was revealed that former Milwauk...          News
# 3      On Christmas day, Donald Trump announced that ...          News
# 4      Pope Francis used his annual Christmas Day mes...          News
# ...                                                  ...           ...
# 29995  The chief executive of the U.S. Aerospace Indu...  politicsNews
# 29996  The following are highlights of the maiden pol...     worldnews
# 29997  If there s one thing President Barack Obama is...          News
# 29998  The Syrian army and its allies have taken full...     worldnews
# 29999  The United States will give Israel $38 billion...  politicsNews
#
#                       date  real       ID
# 0        December 31, 2017     0      NaN
# 1        December 31, 2017     0      NaN
# 2        December 30, 2017     0      NaN
# 3        December 29, 2017     0      NaN
# 4        December 25, 2017     0      NaN
# ...                    ...   ...      ...
# 29995    December 6, 2016      1   6880.0
# 29996    October 11, 2017      1  17818.0
# 29997        June 28, 2016     0   5689.0
# 29998    November 2, 2017      1  15805.0
# 29999  September 14, 2016      1   8143.0
#
# [74898 rows x 6 columns]

# %% [markdown]
# Check for any duplicated entry in our dataset, that might happen since the data may be from the same source or same time period

# %%
df_duplicated = df_news[df_news.duplicated(["title", "text"])]
df_duplicated.sort_values(by=["title"], ascending=True)
# Out:
#                                                    title  \
# 20771  #AnyoneButHillary: NEW POLL Shows Bernie Suppo...
# 17930  #Austin: Fights Break Out Between Police and S...
# 7023   #Austin: Fights Break Out Between Police and S...
# 19211  #Berkeley CRAZY! RIOTERS CHASE And Beat People...
# 10689  #Berkeley CRAZY! RIOTERS CHASE And Beat People...
# ...                                                  ...
# 19149  “Would You Rather Do A Job You Hate And Not Pa...
# 16696  “YOU’RE HIRED!” Trump Pulls Unemployed Vet Fro...
# 28626  “YOU’RE HIRED!” Trump Pulls Unemployed Vet Fro...
# 21428  “You’re Not Welcome!” Obama As Welcome At Rose...
# 6541   “You’re Not Welcome!” Obama As Welcome At Rose...
#
#                                                     text          subject  \
# 20771  Hillary may find out she needs more than black...        left-news
# 17930  Commies carrying flags fought with the Austin ...        left-news
# 7023   Commies carrying flags fought with the Austin ...         politics
# 19211  Is anyone else thinking what we re thinking ab...        left-news
# 10689  Is anyone else thinking what we re thinking ab...        left-news
# ...                                                  ...              ...
# 19149  Filmmaker and patriot, Dennis Michael Lynch is...        left-news
# 16696  No matter which candidate you support, this mo...  Government News
# 28626  No matter which candidate you support, this mo...  Government News
# 21428  Roseberg residents and families of victims are...        left-news
# 6541   Roseberg residents and families of victims are...        left-news
#
#                date  real       ID
# 20771   Apr 6, 2016     0      NaN
# 17930  Sep 23, 2017     0      NaN
# 7023   Sep 23, 2017     0   9841.0
# 19211   Feb 2, 2017     0      NaN
# 10689   Feb 2, 2017     0  19211.0
# ...             ...   ...      ...
# 19149  Feb 12, 2017     0      NaN
# 16696  Mar 21, 2016     0      NaN
# 28626  Mar 21, 2016     0  16696.0
# 21428   Oct 7, 2015     0      NaN
# 6541    Oct 7, 2015     0  21428.0
#
# [12772 rows x 6 columns]

# %%
len(df_duplicated)
# Out:
# 12772

# %%
df_newsnet
# Out:
#                          id  \
# 0      gossipcop-2493749932
# 1      gossipcop-4580247171
# 2       gossipcop-941805037
# 3      gossipcop-2547891536
# 4      gossipcop-5476631226
# ...                     ...
# 23191       politifact14731
# 23192         politifact329
# 23193        politifact1576
# 23194        politifact4720
# 23195          politifact52
#
#                                                 news_url  \
# 0      www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1      hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2      variety.com/2017/biz/news/tax-march-donald-tru...
# 3      www.dailymail.co.uk/femail/article-3499192/Do-...
# 4      variety.com/2018/film/news/list-2018-oscar-nom...
# ...                                                  ...
# 23191  https://www.flake.senate.gov/public/index.cfm/...
# 23192  https://web.archive.org/web/20080131000131/htt...
# 23193         http://www.youtube.com/watch?v=4O8CxZ1OD58
# 23194         http://www.youtube.com/watch?v=EhyMplwY6HY
# 23195  https://web.archive.org/web/20071102131244/htt...
#
#                                                    title  \
# 0      Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1      Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2      Celebrities Join Tax March in Protest of Donal...
# 3      Cindy Crawford's daughter Kaia Gerber wears a ...
# 4          Full List of 2018 Oscar Nominations – Variety
# ...                                                  ...
# 23191  Flake: “Religious tests should have no place i...
# 23192                           Change We Can Believe In
# 23193  deputy director of national health statistics ...
# 23194  Romneys ProLife Conversion Myth or Reality Jun...
# 23195                             Interest Group Ratings
#
#                                                tweet_ids  real
# 0      284329075902926848\t284332744559968256\t284335...     0
# 1      992895508267130880\t992897935418503169\t992899...     0
# 2      853359353532829696\t853359576543920128\t853359...     0
# 3      988821905196158981\t988824206556172288\t988825...     0
# 4      955792793632432131\t955795063925301249\t955798...     0
# ...                                                  ...   ...
# 23191                                                NaN     1
# 23192  634287923135909888\t946743411100536832\t946816...     1
# 23193                                                NaN     1
# 23194                                 188871706637647874     1
# 23195           1002208963239337984\t1024651239697666048     1
#
# [23196 rows x 5 columns]

# %% [markdown]
# # Important decision
#  I"ve decided to drop the FakeNewsNet dataset because it does not provide text content to be analyzed, which is completely different from the other datasets I have. I will move forward with the combination of df_kaggle and df_more.

# %%
df = df_news.drop_duplicates(subset=["title", "text"], keep="last")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 62126 entries, 0 to 29999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    62126 non-null  str
#  1   text     62126 non-null  str
#  2   subject  62126 non-null  str
#  3   date     62126 non-null  str
#  4   real     62126 non-null  int64
#  5   ID       27330 non-null  float64
# dtypes: float64(1), int64(1), str(4)
# memory usage: 153.6 MB

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  real  ID
# 0  December 31, 2017     0 NaN
# 1  December 31, 2017     0 NaN
# 2  December 30, 2017     0 NaN
# 3  December 29, 2017     0 NaN
# 4  December 25, 2017     0 NaN

# %%
df = df.drop(columns=["date", "ID"])

# %% [markdown]
# # Data Exploration

# %% [markdown]
# `df` is now my master dataset, it contains two merged datasets with the total of 62126 entries. That"s a lot of data =)

# %% [markdown]
# First step is to clean our text from any punctuation or any special characters.

# %%
import re
import string
def clean_text(text):
    text = text.lower()
    text = re.sub("[%s]" % re.escape(string.punctuation), "", text)
    text = re.sub("([^x00-x7F])+", " ", text)

    return text

# %%
df["clean_title"] = df["title"].apply(lambda x: clean_text(x))
df["clean_text"] = df["text"].apply(lambda x: clean_text(x))
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  real  \
# 0  Donald Trump just couldn t wish all Americans ...    News     0
# 1  House Intelligence Committee Chairman Devin Nu...    News     0
# 2  On Friday, it was revealed that former Milwauk...    News     0
# 3  On Christmas day, Donald Trump announced that ...    News     0
# 4  Pope Francis used his annual Christmas Day mes...    News     0
#
#                                          clean_title  \
# 0   donald trump sends out embarrassing new ear s...
# 1   drunk bragging trump staffer started russian ...
# 2   sheriff david clarke becomes an internet joke...
# 3   trump is so obsessed he even has obama s name...
# 4   pope francis just called out donald trump dur...
#
#                                           clean_text
# 0  donald trump just couldn t wish all americans ...
# 1  house intelligence committee chairman devin nu...
# 2  on frida it was revealed that former milwaukee...
# 3  on christmas da donald trump announced that he...
# 4  pope francis used his annual christmas da mess...

# %% [markdown]
# Stopwords are considered to be "fillers" so during the analysis I will not consider them in my corpus.

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Barderus_Legion\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop = set(stopwords.words("english"))

# %%
corpus = [word for i in df["clean_text"].str.split().values.tolist() for word in i if (word not in stop)]

# %% [markdown]
# Let"s look at the common words in my corpus

# %%
from collections import Counter
most_common = Counter(corpus).most_common(25)

# %%
df_temp = pd.DataFrame(most_common)
df_temp.columns = ["Common_words","count"]

# %%
fig = px.bar(df_temp, x="count", y="Common_words", title="Most Common Words in corpus", orientation="h", width=700,height=700, color="Common_words")
plotly.offline.plot(fig, filename="../images/CommonWords.html")
fig.show()

# %%
fig = px.treemap(df_temp, path=["Common_words"], values="count",title="Tree of Most Common Words")
plotly.offline.plot(fig, filename="../images/CommonWords2.html")
fig.show()

# %%
words, frequency = [], []
for word, count in most_common:
    words.append(word)
    frequency.append(count)

sns.barplot(x = frequency, y = words)
plt.title("Word Frequency")
plt.savefig(IMAGES_DIR / "wordFrequency.png")

# %% [markdown]
# As we can see, `said`, `trump`, `us` (probably lowercase form of US), `would` and `president` are our most frequent words. A main reason for that is the date range of our data: late 2016 - early 2018. During this time, Trump became the US president, hence his name shows up so many times. Since all the news came from the US, it"s understandable why `us` has a big frequency as well.

# %% [markdown]
# # Wordcloud

# %%
plt.figure(figsize=(10, 10))
text = df["clean_text"].values
cloud = WordCloud(width = 800, height=400, stopwords = STOPWORDS,
                  background_color="white",
                  max_words = 200,
                  ).generate(" ".join(text))
plt.imshow(cloud)
plt.axis("off")
plt.savefig(IMAGES_DIR / "wordcloud.png")
plt.show()

# %% [markdown]
# Now, let"s take a more analytical look at the data

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

# %%
texts = df["clean_text"].tolist()
pos_counts = Counter()

# %% [markdown]
# Let"s see which parts of speech is most frequent in our corpus

# %% [markdown]
# for doc in nlp.pipe(texts, batch_size=100, n_process=1):
#     pos_counts.update([token.pos_ for token in doc])

# %% [markdown]
# Since I don"t have a very powerful computer and the data size is massive, this is taking >30min per run

# %%
df_temp = pd.DataFrame(pos_counts.most_common(15),
                       columns=["Part_of_Speech", "count"])

# %% [markdown]
# Common parts of speech:
# | ag	| Description       |   Example Words |
# |-------|-------------------|-----------------|
# | NN 	| Noun (singular)   | 	cat, tree, algorithm |
# | NS 	| Noun (plural)     |	cats, ideas, datasets |
# | VB 	| Verb (base form)  | 	run, eat, predict |
# | VBD 	| Verb (past tense) | 	ran, ate, predicted |
# | JJ 	| Adjective         | 	red, quick, efficient |
# | RB 	| Adverb            |	quickly, well, always |
# | IN 	| Preposition       |	in, on, of |
# | DT 	| Determiner        |	a, the, some |

# %%
#from textblob import TextBlob

#text = " ".join(df["clean_text"])
#blob = TextBlob(text)
#top = Counter([pos[1] for pos in blob.tags])
#df_temp = pd.DataFrame(top.most_common(15))
#df_temp.columns = ["Part_of_Speech","count"]
fig = px.bar(df_temp, x="Part_of_Speech", y="count", title="Top 15 Part-Of-Speech tagging", width=700,height=700, color="Part_of_Speech")
plotly.offline.plot(fig, filename="../images/POS.html")
fig.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Initialize CountVectorizer
vec = CountVectorizer(stop_words=list(stop), ngram_range=(2, 3  ))

# %%
# Matrix of ngrams
bow = vec.fit_transform(df["clean_text"])

# %%
# Count frequency of ngrams
#count_values = bow.toarray().sum(axis=0) # MemoryError: Unable to allocate 5.03 TiB for an array with shape (62126, 11119763) and data type int64 BIG NO NO NO NO

# %%
sum_words = bow.sum(axis=0)
count_values = np.asarray(sum_words).ravel() # small 1D dense array of length vocab_size

# %%
# Create DataFrame from ngram frequencies
ngram_freq = pd.DataFrame(sorted([(count_values[i], k) for k, i in vec.vocabulary_.items()], reverse = True))
ngram_freq.columns = ["frequency", "ngram"]

# %%
sns.countplot(x="real", data=df, hue="real")
plt.title("Class balance per dataset")
# Out:
# Text(0.5, 1.0, 'Class balance per dataset')

# %% [markdown]
# Average word length in each text

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 62126 entries, 0 to 29999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        62126 non-null  str
#  1   text         62126 non-null  str
#  2   subject      62126 non-null  str
#  3   real         62126 non-null  int64
#  4   clean_title  62126 non-null  str
#  5   clean_text   62126 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 295.2 MB

# %%
print("Label counts:\n", df["real"].value_counts(dropna=False))
print("Fake rows:", df[df["real"] == 0].shape[0])
print("Real rows:", df[df["real"] == 1].shape[0])
# Out:
# Label counts:
#  real
# 1    35619
# 0    26507
# Name: count, dtype: int64
# Fake rows: 26507
# Real rows: 35619

# %%
def avg_word_len(text: pd.Series) -> pd.Series:
    # Make sure we don"t have NaNs
    text = text.fillna("").astype(str).str.strip()
    word_lists = text.str.split()
    avg_len = word_lists.apply(
        lambda words: np.mean([len(w) for w in words]) if len(words) > 0 else np.nan
    )

    return avg_len

# %%
avg_len_high = avg_word_len(df[df["real"] <= 0]["clean_text"]).dropna()

plt.figure(figsize=(6, 4))
sns.histplot(x=avg_len_high, color="red", bins=30)
plt.title("High Complexity - Average Word Length")
plt.xlabel("Average word length")
plt.ylabel("Count")
plt.savefig(IMAGES_DIR / "AverageWordLength_fake.png")
plt.show()

# %%
avg_len_low = avg_word_len(df[df["real"] > 0]["clean_text"]).dropna()

plt.figure(figsize=(6, 4))
sns.histplot(x=avg_len_low, color="blue", bins=30)
plt.title("Low Complexity - Average Word Length")
plt.xlabel("Average word length")
plt.ylabel("Count")
plt.savefig(IMAGES_DIR / "AverageWordLength_real.png")
plt.show()

# %% [markdown]
# Number of Sentences in text

# %%
import re
def count_sentences(text):
    text = str(text)
    parts = re.split(r"[.!?]+", text)
    parts = [p for p in parts if p.strip()]
    return len(parts)

# %%
# High complexity
num_sents_high = df[df["real"] <= 0]["clean_text"].apply(count_sentences)

plt.figure(figsize=(6, 4))
sns.histplot(num_sents_high, color="red", bins=20)
plt.title("High Complexity - Number of Sentences")
plt.xlabel("Sentence count")
plt.ylabel("Count")
plt.show()

# %%
# Low complexity
num_sents_low = df[df["real"] > 0]["clean_text"].apply(count_sentences)

plt.figure(figsize=(6, 4))
sns.histplot(num_sents_low, color="blue", bins=20)
plt.title("Low Complexity - Number of Sentences")
plt.xlabel("Sentence count")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Now let us also compare these with the "target"

# %%
df["text_len"] = df["clean_text"].str.split().map(lambda x: len(x) if isinstance(x, list) else 0)

plt.figure(figsize=(6, 4))
sns.scatterplot(x="text_len", y="real", data=df)
plt.title("Word Count vs Target", fontweight="bold")
plt.xlabel("Word count")
plt.ylabel("Target (real)")
plt.savefig(IMAGES_DIR / "WordCount_x_Target.png")
plt.show()

# %%
df["avg_word_len"] = avg_word_len(df["clean_text"])
df = df.reset_index(drop=True)

plt.figure(figsize=(6, 4))
sns.scatterplot(x="avg_word_len", y="real", data=df, color="red")
plt.title("Average Word Length vs Target", fontweight="bold")
plt.xlabel("Average word length")
plt.ylabel("Target (real)")
plt.savefig(IMAGES_DIR / "AverageWordLength_x_Target.png")
plt.show()

# %%
df["num_sents"] = df["clean_text"].apply(
    lambda x: len(str(x).split("\n"))
)

plt.figure(figsize=(6, 4))
sns.scatterplot(x="num_sents", y="real", data=df, color="orange")
plt.title("Sentence Count vs Target", fontweight="bold")
plt.xlabel("Sentence count")
plt.ylabel("Target (real)")
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
corr = df.select_dtypes(include=[np.number]).corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap="YlGnBu", center=0, square=True,
            linewidths=.5, annot=True)
plt.savefig(IMAGES_DIR / "heatmap.png")
plt.show()

# %%
from textblob import TextBlob

df["polarity"] = df["clean_text"].apply(lambda x: TextBlob(x).sentiment.polarity)
df["subjectivity"] = df["clean_text"].apply(lambda x: TextBlob(x).sentiment.subjectivity)

sns.boxplot(x="real", y="polarity", data=df)
plt.title("Sentiment Polarity by Label")
plt.savefig(IMAGES_DIR / "SentimentPolarityByLabel.png")
plt.show()

# %% [markdown]
# ## Final export validation
#
# Before writing the master dataset, verify the downstream contract for later preprocessing and modeling notebooks.

# %%
required_columns = [
    "title",
    "text",
    "real",
    "clean_text",
    "polarity",
    "subjectivity",
    "text_len",
    "avg_word_len",
]
missing_columns = [column for column in required_columns if column not in df.columns]
assert not missing_columns, f"Missing required columns before export: {missing_columns}"

export_frame = df.copy()
export_frame = export_frame.dropna(subset=["text", "clean_text", "real"])
export_frame["real"] = export_frame["real"].astype(int)
export_frame = export_frame.reset_index(drop=True)

print("Export rows:", len(export_frame))
print("Label distribution:")
print(export_frame["real"].value_counts(dropna=False))
print("Duplicate text rows:", export_frame.duplicated(subset=["text"]).sum())
# Out:
# Export rows: 62126
# Label distribution:
# real
# 1    35619
# 0    26507
# Name: count, dtype: int64
# Duplicate text rows: 6136

# %%
export_frame.to_csv(PREPROCESSED_DIR / "master_fakenews.csv", index=False)
