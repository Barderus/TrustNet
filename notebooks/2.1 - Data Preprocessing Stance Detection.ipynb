# %% [markdown]
# # Stance Detection Data Preprocessing
#
# This notebook is now a lightweight review layer. The repeatable stance preprocessing logic lives in `utils/preprocessing.py` and the command-line entry point is `script/preprocess_data.py`.
#
# Use this notebook to inspect generated artifacts and validate assumptions. Keep production preprocessing in Python modules.

# %% [markdown]
# ## Rebuild Artifacts
#
# From the project root, run:
#
# ```bash
# uv run python script/preprocess_data.py
# ```
#
# Expected outputs:
#
# - `data/preprocessed/master_stance.csv`
# - `data/preprocessed/stance_preprocessed.csv`

# %%
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path(r"C:\Users\Barderus_Legion\PycharmProjects\TrustNet")
DATA_DIR = PROJECT_ROOT / "data"
preprocessed_dir = DATA_DIR / "preprocessed"
master_path = preprocessed_dir / "master_stance.csv"
model_path = preprocessed_dir / "stance_preprocessed.csv"

master_path, model_path
# Out:
# (WindowsPath('C:/Users/Barderus_Legion/PycharmProjects/TrustNet/data/preprocessed/master_stance.csv'),
#  WindowsPath('C:/Users/Barderus_Legion/PycharmProjects/TrustNet/data/preprocessed/stance_preprocessed.csv'))

# %%
master = pd.read_csv(master_path)
model_ready = pd.read_csv(model_path)

master.shape, model_ready.shape
# Out:
# ((49972, 13), (49972, 18))

# %%
model_ready[["Headline", "Stance", "headline_prep", "body_prep", "combined_text"]].head()
# Out:
#                                             Headline     Stance  \
# 0  Police find mass graves with at least '15 bodi...  unrelated
# 1  Hundreds of Palestinians flee floods in Gaza a...      agree
# 2  Christian Bale passes on role of Steve Jobs, a...  unrelated
# 3  HBO and Apple in Talks for $15/Month Apple TV ...  unrelated
# 4  Spider burrowed through tourist's stomach and ...   disagree
#
#                                        headline_prep  \
# 0  police mass graves bodies near mexico town stu...
# 1  hundreds palestinians flee floods gaza israel ...
# 2  christian bale passes role steve jobs actor re...
# 3  hbo apple talks month apple tv streaming servi...
# 4              spider burrowed tourist stomach chest
#
#                                            body_prep  \
# 0  danny boyle directing untitled film seth rogen...
# 1  hundreds palestinians evacuated homes sunday m...
# 2  year old moscow resident hospitalized wounds i...
# ...

# %%
model_ready["Stance"].value_counts(dropna=False).rename_axis("stance").reset_index(name="count")
# Out:
#       stance  count
# 0  unrelated  36545
# 1    discuss   8909
# 2      agree   3678
# 3   disagree    840
