# %% [markdown]
# # Fake-News Data Preprocessing
#
# This notebook is now a lightweight review layer. The repeatable preprocessing logic lives in `utils/preprocessing.py` and the command-line entry point is `script/preprocess_data.py`.
#
# Use this notebook to inspect inputs, run small validation checks, and interpret the generated preprocessing artifacts. Avoid adding production preprocessing logic here.

# %% [markdown]
# ## Rebuild Artifacts
#
# From the project root, run:
#
# ```bash
# uv run python script/preprocess_data.py
# ```
#
# Expected outputs:
#
# - `data/preprocessed/master_fakenews.csv`
# - `data/preprocessed/fakenews_preprocessed.csv`

# %%
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path(r"C:\Users\Barderus_Legion\PycharmProjects\TrustNet")
DATA_DIR = PROJECT_ROOT / "data"
preprocessed_dir = DATA_DIR / "preprocessed"
master_path = preprocessed_dir / "master_fakenews.csv"
model_path = preprocessed_dir / "fakenews_preprocessed.csv"

master_path, model_path
# Out:
# (WindowsPath('C:/Users/Barderus_Legion/PycharmProjects/TrustNet/data/preprocessed/master_fakenews.csv'),
#  WindowsPath('C:/Users/Barderus_Legion/PycharmProjects/TrustNet/data/preprocessed/fakenews_preprocessed.csv'))

# %%
master = pd.read_csv(master_path)
model_ready = pd.read_csv(model_path)

master.shape, model_ready.shape
# Out:
# ((62126, 11), (62126, 27))

# %%
model_ready[["title", "real", "prep_text", "word_count", "lexical_richness"]].head()
# Out:
#                                                title  real  \
# 0   Donald Trump Sends Out Embarrassing New Year’...     0
# 1   Drunk Bragging Trump Staffer Started Russian ...     0
# 2   Sheriff David Clarke Becomes An Internet Joke...     0
# 3   Trump Is So Obsessed He Even Has Obama’s Name...     0
# 4   Pope Francis Just Called Out Donald Trump Dur...     0
#
#                                            prep_text  word_count  \
# 0  donald trump sends embarrassing new year eve m...         267
# 1  drunk bragging trump staffer started russian c...         179
# 2  sheriff david clarke internet joke threatening...         338
# 3  trump obsessed obama coded website images chri...         235
# 4  pope francis just called donald trump christma...         198
#
#    lexical_richness
# 0          0.588015
# 1          0.765363
# 2          0.644970
# 3          0.638298
# 4          0.747475

# %%
model_ready["real"].value_counts(dropna=False).rename_axis("label").reset_index(name="count")
# Out:
#    label  count
# 0      1  35619
# 1      0  26507
