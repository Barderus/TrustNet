# %%
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder

import torch
import pandas as pd
# Out:
# C:\Users\Owner\PycharmProjects\TrustNet\.venv\Lib\site-packages\transformers\utils\generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\Owner\PycharmProjects\TrustNet\.venv\Lib\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %%
df = pd.read_csv("../Data/preprocessed/stance_preprocessed.csv")

# %%
df["combined"] = (
        df["headline_prep"].fillna("").astype(str) +
        " [SEP] " +
        df["body_prep"].fillna("").astype(str)
)

X = df["combined"].astype(str).tolist()

# %%
le = LabelEncoder()
y = le.fit_transform(df["Stance"])

# %%
num_classes = len(le.classes_)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")
# Out:
# C:\Users\Owner\PycharmProjects\TrustNet\.venv\Lib\site-packages\huggingface_hub\file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
max_len = 128

# %%
print(type(X_train[0]))
print(X_train[:5])
# Out:
# <class 'str'>
# ['accountant claim comcast got fired job reporting customer service issue [SEP] innovative might first word come mind describing u telephone cable company comcast giving company credit credit due let u face harrowing minute customer service call went viral july looked like comcast nothing strive reached peak horrible yet report week accurate comcast continued shine innovator competitive field corporate terribleness got customer employer fire complaining shoddy customer service full story sadistic glory consumerist sparknotes version customer named conal started subscribing comcast service early issue erroneous charge bill never arrived discount applied conal considered cancelling service decided stick comcast rep promised issue would resolved threw free perk another friendly gesture company also allegedly sent billed conal equipment would never ordered get crazy conal understandably frustrated decided bypass customer service department take complaint straight comcast controller call claim suggested private sector oversight group look comcast billing accounting issue shortly call comcast contacted conal employer large accounting firm consumerist report happened business comcast rep claimed conal name dropped employer leverage call according story firm opened investigation conal fired job hard know telling truth conal tell consumerist never mentioned employer someone comcast must looked figure worked comcast part allegedly refused release tape phone call made matter little strange conal invoke company name threatening way comcast could easily prove much excerpting relevant portion call much monitoring quality assurance purpose want done right record call article originally appeared slate republished permission', 'batmobile stolen batman v superman dawn justice set zack snyder know [SEP] ok still rumor chance batmobile stolen set batman v superman set detroit former employer bleeding cool posted scuttlebutt source detroit one batmobile model used filming batman v superman gone missing believed stolen would first time batmobile nicked detroit though replica tv series version back far clue confirmation true quickly form list suspect money king tut stay tuned update rumor dispelling rumor want hear always leave u thought opinion comment want batman download fansided com app batman news forget like caped crusade facebook follow u twitter really love batman caped crusade always looking volunteer writer leave u comment email capedcrusades gmail com apply fansided com', 'priest claim seeing god woman dismissed hoax [SEP] get patheos atheist newsletter follow patheos atheist home ask richard podcasts speaking contributor medium contact submission book kirk cameron saving christmas several award awful film patheos blogger loses book deal nori publishing pro gay advocacy hoax alert father neal met god think woman made like god february terry firma comment impossible fool certainly bit rich typo grammatical error original catholic priest massachussetts officially dead minute medic able miraculously start heart time father john micheal neal claim went heaven met god describes warm comforting motherly figure story various iteration popping news feed day even apart matter god gender offer thought matter religious near death experience addressed truth article hoax falsehood probably designed attract cheap click year old father john michael neal massachusetts whose heart failure required hospitalization met god minute detour heaven go shutterstock search old man hospital bed photo among top result find image stock photo site like dreamstime photolia best tell story originated world news daily report early february publication claim american jewish zionist newspaper tel aviv unleashes world fine fare california man get pound penile implant become pornstar world famous taj mahal turned star hotel hollywood famous butt double found dead motel room perhaps supposed satire since tale father neal initially picked mostly african news medium low news st ...

# %%
train_enc = tokenizer(
    X_train,
    padding="max_length",
    truncation=True,
    max_length=max_len,
    return_tensors="pt"
)

# %%
val_enc = tokenizer(
    X_val,
    padding="max_length",
    truncation=True,
    max_length=max_len,
    return_tensors="pt"
)

# %%
train_input_ids = train_enc["input_ids"]
train_attention = train_enc["attention_mask"]
train_labels_tensor = torch.tensor(y_train)

# %%
val_input_ids = val_enc["input_ids"]
val_attention = val_enc["attention_mask"]
val_labels_tensor = torch.tensor(y_val)

# %%
device = "cpu"

# %%
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=num_classes
).to(device)
# Out:
# C:\Users\Owner\PycharmProjects\TrustNet\.venv\Lib\site-packages\huggingface_hub\file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.weight', 'classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
batch_size = 8
num_epochs = 2

# %%
for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i in range(0, len(train_input_ids), batch_size):
        batch_input = train_input_ids[i:i+batch_size].to(device)
        batch_mask  = train_attention[i:i+batch_size].to(device)
        batch_labels = train_labels_tensor[i:i+batch_size].to(device)

        optimizer.zero_grad()

        outputs = model(input_ids=batch_input, attention_mask=batch_mask)
        logits = outputs.logits

        loss = criterion(logits, batch_labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs} - Loss: {total_loss:.4f}")
# Out:
# Epoch 1/2 - Loss: 1167.4377
# Epoch 2/2 - Loss: 504.6964

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
val_dataset = TensorDataset(val_input_ids, val_attention, val_labels_tensor)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# Create validation batch otherwise, it requires over 50GB of memory to validate the model

# %%
model.eval()
all_preds = []
all_labels = []

# %%
all_logits = []

# %%
with torch.no_grad():
    for ids, mask, labels in val_loader:
        ids = ids.to(device)
        mask = mask.to(device)

        logits = model(input_ids=ids, attention_mask=mask).logits
        preds = logits.argmax(dim=1).cpu().numpy()

        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

# %%
acc  = accuracy_score(all_labels, all_preds)
prec = precision_score(all_labels, all_preds, average="weighted")
rec  = recall_score(all_labels, all_preds, average="weighted")
f1   = f1_score(all_labels, all_preds, average="weighted")

# %%
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1 Score:  {f1:.4f}")
# Out:
# Accuracy:  0.9671
# Precision: 0.9704
# Recall:    0.9671
# F1 Score:  0.9682

# %%
model.save_pretrained("distilbert_stanceD")
tokenizer.save_pretrained("distilbert_tokenizer_stanceD")
# Out:
# ('distilbert_tokenizer_stanceD\\tokenizer_config.json',
#  'distilbert_tokenizer_stanceD\\special_tokens_map.json',
#  'distilbert_tokenizer_stanceD\\vocab.txt',
#  'distilbert_tokenizer_stanceD\\added_tokens.json',
#  'distilbert_tokenizer_stanceD\\tokenizer.json')
